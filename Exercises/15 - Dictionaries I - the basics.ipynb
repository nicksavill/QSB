# %% [markdown]
# ### Exercise 15.1
#
# ![mushrooms.jpg](attachment:mushrooms.jpg)
#
# Create a dictionary called `mushrooms` containing the data in the following table. Print it.
#
# |Scientific Name|	Common Name|
# |:-------|:-------|
# |*Fistulina hepatica*	|Beefsteak|
# |*Laetiporus sulphureus*	|Chicken-of-the-Woods|
# |*Flammulina velutipes* |Enoki|
# |*Hericium erinaceus*	|Lion’s Mane|
#
# <div class="alert alert-info">
# Your answer should be {'Fistulina hepatica': 'Beefsteak', 'Laetiporus sulphureus': 'Chicken-of-the-Woods', etc.}.
#
# </div>

# %% [markdown]
# ### Exercise 15.2
#
# Add the following items to `mushrooms`: <br>
# *Pleurotus pulmonarius*: Summer oyster <br>
# *Pleurotus euosmos*: Tarragon <br>

# %% [markdown]
# ### Exercise 15.3
#
# Using your dictionary, print the common name for *Laetiporus sulphureus*.
#
# <div class="alert alert-info">
# Your answer should be Chicken-of-the-Woods.
#
# </div>

# %% [markdown]
# ### Exercise 15.4
#
# Replace the common name for *Laetiporus sulphureus* with Sulphur Shelf (this is another common name for this species which forms striking golden-yellow shelf-like fungal structures on tree trunks and branches.)

# %% [markdown]
# ### Exercise 15.5
#
# Test if the species *Pholiota nameko* is in `mushrooms`.
#
# <div class="alert alert-info">
# Your answer should be Pholiota nameko is not in mushrooms.
#
# </div>

# %% [markdown]
# ### Exercise 15.6
#
# Create an empty dictionary called `books` and print it.
#
# <div class="alert alert-info">
# Your answer should be {}.
#
# </div>

# %% [markdown]
# ### Exercise 15.7
#
# Add the following two books to your dictionary `books` and print it.
#
# Book title | Authour
# :--- | :---
# The chimpanzees of Gombe | Jane Goodall
# The blind watchmaker | Richard Dawkins
#
# <div class="alert alert-info">
# Your answer should be {'The chimpanzees of Gombe': 'Jane Goodall', 'The blind watchmaker': 'Richard Dawkins'}.
#
# </div>
